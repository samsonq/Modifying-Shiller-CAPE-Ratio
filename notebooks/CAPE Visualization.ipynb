# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mlp
import seaborn as sns
# %matplotlib inline
mlp.style.use("seaborn")

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("../data/df.csv")
df.head()
# Out:
#       Date     P     D    E    CPI  Date Fraction  Long Interest Rate GS10  \
# 0  1871.01  4.44  0.26  0.4  12.46        1871.04                     5.32
# 1  1871.02  4.50  0.26  0.4  12.84        1871.13                     5.32
# 2  1871.03  4.61  0.26  0.4  13.03        1871.21                     5.33
# 3  1871.04  4.74  0.26  0.4  12.56        1871.29                     5.33
# 4  1871.05  4.86  0.26  0.4  12.27        1871.38                     5.33
#
#    Real Price  Real Dividend  Real TR Price   ...  Real Total BondReturns  \
# 0       97.25           5.69           97.25  ...                    1.00
# 1       95.64           5.53           96.10  ...                    0.97
# 2       96.55           5.45           97.47  ...                    0.96
# 3      103.03           5.65          104.49  ...                    1.00
# 4      108.10           5.78          110.12  ...                    1.03
#
#   10 year anualized stock real return  10 year annualized Real Return  \
# 0                              13.06%                           9.25%
# 1                              13.09%                           9.46%
# 2                              13.10%                           9.62%
# 3                              12.21%                           9.10%
# 4                              12.26%                           8.95%
#
#    Real 10 year excess annualizedReturns Real TR Price  float  \
# 0                                  3.81%                97.25
# 1                                  3.62%                96.10
# 2                                  3.48%                97.47
# 3                                  3.11%               104.49
# 4                                  3.31%               110.12
#
#    Real TR Scaled  Earnings  float  Excess CAPE Yield float  \
# 0                             8.76                      NaN
# 1                             8.54                      NaN
# 2                             8.46                      NaN
# 3                             8.82                      NaN
# 4                             9.06                      NaN
#
#   10 year anualized stock real return float  \
# 0                                     13.06
# 1                                     13.09
# 2                                     13.10
# 3                                     12.21
# 4                                     12.26
#
#   10 year annualized Real Return float  \
# 0                                 9.25
# 1                                 9.46
# 2                                 9.62
# 3                                 9.10
# 4                                 8.95
#
#   Real 10 year excess annualizedReturns float
# 0                                        3.81
# 1                                        3.62
# 2                                        3.48
# 3                                        3.11
# 4                                        3.31
#
# [5 rows x 26 columns]

# %%
df['E10'] = df['Real Earnings'].rolling(window=120, min_periods=120).mean()
df["P/E10"] = df['Real Price'] / df['E10']

# %%
plt.plot(df["Date Fraction"], df["Real Price"])
plt.title("Historical S&P Prices")
plt.xlabel("Date")
plt.ylabel("Stock Price, P")
# Out:
# Text(0, 0.5, 'Stock Price, P')

# %%
plt.plot(df["Date Fraction"], df["Real Earnings"], label="E")
plt.plot(df["Date Fraction"], df["E10"], label="E10")
plt.title("Historical S&P Earnings")
plt.xlabel("Date")
plt.ylabel("Earnings, E")
plt.legend()

# %%
plt.plot(df["Date Fraction"], df["Real Dividend"])
plt.title("Historical S&P Dividends")
plt.xlabel("Date")
plt.ylabel("Dividends, D")
# Out:
# Text(0, 0.5, 'Dividends, D')

# %%
plt.plot(df["Date Fraction"], df["CAPE"], label="CAPE")
plt.plot(df["Date Fraction"], df["P/E10"], label="CAPE_Reconstructed")
plt.title("Historical S&P CAPE")
plt.xlabel("Date")
plt.ylabel("P/E10")
plt.legend()

# %%
df["10 yr. MAE growth"] = np.log(df.E10.shift(-12)/df.E10.shift())/10
plt.xscale('log')
plt.scatter(df["CAPE"], df["10 yr. MAE growth"])
plt.ylabel("10 Year MA(E) Growth")
plt.xlabel("CAPE, P/E10")
plt.title("Ten Year MA(E) Growth vs CAPE")
# Out:
# Text(0.5, 1.0, 'Ten Year MA(E) Growth vs CAPE')

# %%
df["10 yr. P growth"] = np.log(df.P.shift(-120)/df.P)/10
plt.xscale('log')
plt.scatter(df["CAPE"], df["10 yr. P growth"])
plt.ylabel("10 Year P Growth")
plt.xlabel("CAPE, P/E10")
plt.title("Ten Year Price Growth vs CAPE")
# Out:
# Text(0.5, 1.0, 'Ten Year Price Growth vs CAPE')
